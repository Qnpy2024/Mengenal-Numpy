# %% [markdown]
# <a href="https://colab.research.google.com/github/Qnpy2024/Mengenal-Numpy/blob/main/FirstWeekTask/Pertemuan_1_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('/content/drive/MyDrive/2024 1 Visualisasi Data & Analisis Eksplorasi Data/Salary_Data.csv')
data
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
 data.head(5)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.shape
# Out:
# (6704, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
data.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
data.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
x = data.iloc[:,4]
x.head(10)
# Out:
# 0     5.0
# 1     3.0
# 2    15.0
# 3     7.0
# 4    20.0
# 5     2.0
# 6    12.0
# 7     4.0
# 8     1.0
# 9    10.0
# Name: Years of Experience, dtype: float64

# %%
y = data.iloc[:,-1]
y.head(5)
# Out:
# 0     90000.0
# 1     65000.0
# 2    150000.0
# 3     60000.0
# 4    200000.0
# Name: Salary, dtype: float64

# %%
plt.scatter(x,y)
plt.title('Experience vs Salary')
plt.xlabel('Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=51)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4487,)
# (2211,)
# (4487,)
# (2211,)

# %%
linear = LinearRegression()
linear.fit(np.array(x_train).reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([7166.06147074])

# %%
linear.intercept_
# Out:
# 57492.303425811864

# %%
Y_pred = linear.predict(np.array(x_test).reshape(-1,1))

# %%
Y_pred
# Out:
# array([129152.9181332 , 157817.16401616, 100488.67225025, ...,
#        186481.40989912, 172149.28695764,  71824.42636729])

# %%
y_test
# Out:
# 4260    113000.0
# 5702    190000.0
# 1084    150000.0
# 3302    140000.0
# 2486    161393.0
#           ...
# 109      40000.0
# 6568     35000.0
# 5214    180000.0
# 5689    200000.0
# 5569     50000.0
# Name: Salary, Length: 2211, dtype: float64

# %%
score = r2_score(y_test,Y_pred)
score
# Out:
# 0.6560942628977491

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,Y_pred,color='red')
plt.title('Experience vs Salary')
plt.xlabel('Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
